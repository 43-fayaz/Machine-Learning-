# %%
def sayhello(name,no_of_times):
    for i in range(no_of_times):
        print("hi {}".format(name))
sayhello("fayaz",5);
# Out:
# hi fayaz
# hi fayaz
# hi fayaz
# hi fayaz
# hi fayaz

# %%
def add(a,b):
    return a+b;
add(5,6)
# Out:
# 11
